# %% [markdown]
# <a href="https://colab.research.google.com/github/p-mutylina/project01/blob/master/test_if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = 'Python'
if p == 'Python':
  p = 'C++'
print('Язык програмирования:', p)
# Out:
# Язык програмирования: C++

# %%
a = 144
if a%2 ==0:
  print('Четное')
else:
  print('Нечетное')
# Out:
# Четное

# %%
p = 'Python'
if p == 'C++':
  p = 'Fortran'
if p != 'Python':
    p = 'C++'
print ('Язык програмирования:', p)
# Out:
# Язык програмирования: Python
